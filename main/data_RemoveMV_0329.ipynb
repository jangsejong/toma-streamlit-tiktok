# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import streamlit as st

# %% [markdown]
# Data Prepration

# %%
DATA_PATH = 'C:/streamlit-tiktok/toma-streamlit-tiktok/toma-streamlit-tiktok/csv/'
tiktok_dataset = pd.read_csv(f'{DATA_PATH}bq-results-20230329-085959-1680080406863.csv', encoding='utf-8')

# %%
for col in tiktok_dataset.columns:
    n_nan = tiktok_dataset[col].isnull().sum()
    if n_nan>0:
      msg = '{:^20}에서 결측치 개수 : {}개'.format(col,n_nan)
      print(msg)
# Out:
# collected_videos_count에서 결측치 개수 : 6882개
#   collection_time   에서 결측치 개수 : 6882개
#    influencer_id    에서 결측치 개수 : 6882개
#  profile_pic_url_hd 에서 결측치 개수 : 85175개
#          id         에서 결측치 개수 : 6882개
#       nickname      에서 결측치 개수 : 6882개
#      followers      에서 결측치 개수 : 6882개
#        hearts       에서 결측치 개수 : 6882개
#     videos_count    에서 결측치 개수 : 6882개

# %%
dt_tiktok = tiktok_dataset.drop([tiktok_dataset.columns[3]],axis=1)
DF_tiktok1 = dt_tiktok.drop([dt_tiktok.columns[7]],axis=1)
DF_tiktok2 = DF_tiktok1.drop([DF_tiktok1.columns[2]],axis=1)

# %%
DF_tiktok2 = DF_tiktok2[DF_tiktok2['nickname'].notna()]
DF_tiktok2.shape
# Out:
# (86446, 6)

# %%
for col in DF_tiktok2.columns:
    n_nan = DF_tiktok2[col].isnull().sum()
    if n_nan>0:
      msg = '{:^20}에서 결측치 개수 : {}개'.format(col,n_nan)
      print(msg)
    else:
      print('결측치가 없습니다.')
# Out:
# 결측치가 없습니다.
# 결측치가 없습니다.
# 결측치가 없습니다.
# 결측치가 없습니다.
# 결측치가 없습니다.
# 결측치가 없습니다.

# %%
DF_tiktok2 = pd.DataFrame(data=DF_tiktok2, index=None, columns=None, dtype=None, copy=False)
DF_tiktok2.shape
DF_tiktok2.columns
print(DF_tiktok2)
# Out:
#        collected_videos_count  collection_time                id  \
# 234                       0.0     1.674149e+12       linhngadang
# 235                       0.0     1.674150e+12        zynzgyniee
# 236                       0.0     1.674150e+12      chinghateyou
# 237                       0.0     1.674149e+12            _myiin
# 238                       0.0     1.674149e+12           vzminah
# ...                       ...              ...               ...
# 93323                    10.0     1.678123e+12   dinhtrangthao03
# 93324                    10.0     1.678124e+12          emwearvn
# 93325                    10.0     1.678123e+12         whitelazz
# 93326                    10.0     1.678124e+12          cheapyvn
# 93327                    10.0     1.678123e+12  cocosin.official
#
#               nickname  followers       hearts
# 234      Linh Nga Dang       42.0          0.0
# 235           Khánh Hà      177.0          0.0
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import json
import pickle
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot, plot
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import matplotlib
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import ExtraTreesRegressor

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df_tiktok_dataset = DF_tiktok2
df_tiktok_dataset.head(5)
df_tiktok_dataset.info()
df_tiktok_dataset.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86446 entries, 234 to 93327
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   collected_videos_count  86446 non-null  float64
#  1   collection_time         86446 non-null  float64
#  2   id                      86446 non-null  object
#  3   nickname                86446 non-null  object
#  4   followers               86446 non-null  float64
#  5   hearts                  86446 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 4.6+ MB
# (86446, 6)

# %%
data = df_tiktok_dataset[['collected_videos_count','collection_time','id','nickname', 'followers','hearts']]
data.isnull().sum()
# Out:
# collected_videos_count    0
# collection_time           0
# id                        0
# nickname                  0
# followers                 0
# hearts                    0
# dtype: int64

# %% [markdown]
# Modeling and Viz

# %%
df_unique_videos = df_tiktok_dataset.drop_duplicates(subset='id', keep="first")

# %%
# Focus on dataset from 0 till 50.000 likes
df_videos_users_focus = df_unique_videos[df_unique_videos['collected_videos_count'] >= 1]

# %%
### get the output df to use in app.py :
# Focus on more than 10 data sets of likes
df_videos_users_focus = df_unique_videos[df_unique_videos['collected_videos_count'] >= 1]
df_videos_users_focus.to_csv('df_videos_users_focus_0329.csv',index=False)

# %%
# Create a scatter plot with a trendline
fig = px.scatter(df_videos_users_focus, trendline="ols",
                 x="hearts", 
                 y="followers",
                 labels={
                     "hearts": "hearts",
                     "followers": "followers"
                 },
                 log_y=True,
                 trendline_color_override="#FF69B4", 
                 template='plotly_white')

fig.update_traces(marker=dict(
                     color='#674ea7',
                     opacity=0.7,
                 ))
fig.show()
